# %% [markdown]
# # Named Entity Recognition
#
# We can use spaCy to process natural languages, identify part of speech of each tokens, and determine the named entity recognition of some tokens

# %%
import spacy
from spacy import displacy
import pandas as pd
nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('./data/Articles.csv', sep=",", encoding= 'unicode_escape')

# %%
def clean(doc):
    final_token = [token.lemma_ for token in doc if not token.is_stop]
    return " ".join(final_token)

# %%
df['Article'] = df['Article'].apply(lambda x : clean(nlp(x)))

# %%
doc = []
for i in range(50):
    doc += [nlp(df['Article'][i])]

# %%
displacy.render(nlp(clean(doc[30])), style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     London
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  : global oil price slide
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  follow - day rally dealer divide commodity plunge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 60 percent
# ...

# %%
doc2 = nlp(u'I can\'t stand this bloddy thing. It does it every stinking time!')
final = [token.lemma_ for token in doc2 if not token.is_punct]
" ".join(final)
# Out:
# 'I can not stand this bloddy thing it do it every stink time'
